# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns


x = np.arange(0, 10, 0.2)
y = np.sin(x)

x
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. ,
#        5.2, 5.4, 5.6, 5.8, 6. , 6.2, 6.4, 6.6, 6.8, 7. , 7.2, 7.4, 7.6,
#        7.8, 8. , 8.2, 8.4, 8.6, 8.8, 9. , 9.2, 9.4, 9.6, 9.8])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y)

# %%
import seaborn as sns

sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
x = np.random.randn(500)
plt.plot(stats.cumfreq(x, numbins=10)[0])
print(stats.cumfreq(x, numbins=10)[0])
print(np.max(x))
# Out:
# [  1.   6.  26.  93. 192. 328. 447. 491. 498. 500.]
# 3.0251792109337208

# %%
index = np.arange(5)
y = index**2
errorBar = index/2
print(errorBar)
plt.errorbar(index,y, xerr=errorBar, yerr=errorBar, fmt='o', capsize=5,capthick=3)
# Out:
# [0.  0.5 1.  1.5 2. ]
# <ErrorbarContainer object of 3 artists>

# %%
x = np.random.randn(300)
plt.boxplot(x, '*')
# Out:
# C:\Users\Elot\AppData\Local\Temp\ipykernel_3852\3724012640.py:2: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.boxplot(x, '*')
# {'whiskers': [<matplotlib.lines.Line2D at 0x187b8109d30>,
#   <matplotlib.lines.Line2D at 0x187b8109e80>],
#  'caps': [<matplotlib.lines.Line2D at 0x187b8109fd0>,
#   <matplotlib.lines.Line2D at 0x187b810a120>],
#  'boxes': [<matplotlib.lines.Line2D at 0x187b8109be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x187b810a270>],
#  'fliers': [<matplotlib.lines.Line2D at 0x187b810a3c0>],
#  'means': []}

# %%
import pandas as pd

# %%
nd = stats.norm
data = nd.rvs(size=(100))

nd2 = stats.norm(loc=3, scale=1.5)
data2 = nd2.rvs(size=(100))

df = pd.DataFrame({'Boy':data2, 'Girl': data})
sns.violinplot(df)
# Out:
# <Axes: >
